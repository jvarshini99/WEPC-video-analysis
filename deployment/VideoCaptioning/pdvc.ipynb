# %% [markdown]
# # How to Run PDVC on Colab
#
# Clone the repository:

# %%
# !git clone --recursive https://github.com/ttengwang/PDVC.git
# Out:
# fatal: destination path 'PDVC' already exists and is not an empty directory.

# %% [markdown]
# Install the required packages:

# %%
# !pip install matplotlib numpy pandas Pillow PyYAML six tensorboardX colorlog scipy pandas h5py av joblib tqdm google_trans_new torch torchvision opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# Make the required files:

# %%
# %%shell
# cd PDVC/pdvc/ops
# sh make.sh
# Out:
# running build
# running build_py
# running build_ext
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:476: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:398: UserWarning: There are no x86_64-linux-gnu-g++ version bounds defined for CUDA version 11.8
#   warnings.warn(f'There are no {compiler_name} version bounds defined for CUDA version {cuda_str_version}')
# running install
# /usr/lib/python3.10/distutils/cmd.py:62: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
# ...

# %% [markdown]
# Download the model ([anet_tsp_pdvc](https://drive.google.com/drive/folders/1sX5wTk1hBgR_a5YUzpxFCrzwkZQXiIab)) and put it in ./save
# ![image.png](data:image/png;base64,...)
#
# Move the videos to run into the video_folder path
#
# Then run the below code. If the code throws an error due to a [dvc_results.json](https://github.com/ttengwang/PDVC/issues/14), try rerunning the code block again. Eventually it will work.

# %%
# %%shell
# video_folder=visualization/videos
# output_folder=visualization/output
# pdvc_model_path=save/model-best.pth
# # pdvc_model_path=save/anet_tsp_pdvc/model-best.pth
# output_language=en
# cd PDVC
# bash test_and_visualize.sh $video_folder $output_folder $pdvc_model_path $output_language
# Out:
# START GENERATE METADATA
# Namespace(video_folder='visualization/videos', ext='mp4', output_csv='visualization/videos/metadata.csv', workers=20)
# Number of video files: 1
# Saved metadata to visualization/videos/metadata.csv
# mkdir: missing operand
# Try 'mkdir --help' for more information.
# START EXTRACT VIDEO FEATURES
# Namespace(data_path='visualization/videos', metadata_csv_filename='visualization/videos/metadata.csv', backbone='r2plus1d_34', device='cuda', released_checkpoint='r2plus1d_34-tsp_on_activitynet', local_checkpoint=None, clip_len=16, frame_rate=15, stride=16, batch_size=32, workers=8, output_dir='visualization/output/r2plus1d_34-tsp_on_activitynet_stride_16/', shard_id=0, num_shards=1)
# TORCH VERSION:  2.0.0+cu118
# TORCHVISION VERSION:  0.15.1+cu118
# LOADING DATA
# shard-id: 1 out of 1, total number of videos: 1, shard size 1 videos
# Number of videos to process after excluding the ones already computed on disk: 0
# CREATING DATA LOADER
# ...
